# %% [markdown]
# ### Veri formatları
#
# Veri bilimciler olarak, genellikle çeşitli kaynaklardan çeşitli dosya formatlarında(CSV, JSON, XML, TXT, vb) gelen verileri almamız ve işlememiz gerekir.
#
# Pandas kütüphanesinin [IO tools](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html) ile pek çok veri seti türünü yükleyebiliriz. Hızlıca verileri [Pandas Profiling Report](https://github.com/ydataai/ydata-profiling) ile inceleyebiliriz.

# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.DataFrame(np.random.rand(100, 5), columns=["a", "b", "c", "d", "e"])
profile = ProfileReport(df, title="Profiling Report")
profile.to_file("../outputs/test-profiling.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# To get multi output in jupyternotebook
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

## Kullanılacak kütüphaneleri hazır edelim
import matplotlib.pyplot as plt
import seaborn as sns 

import pandas as pd
import numpy as np

import json
import xmltodict
import xml.etree.ElementTree as ET

from zipfile import ZipFile
from io import BytesIO
from urllib.request import urlopen
from urllib.parse import urlencode
from mpl_toolkits.basemap import Basemap # conda install basemap

# %% [markdown]
# #### CSV (Comma Separated Values)
#
# CSV, her veri satırının bir satır olarak gösterildiği ve veri alanlarının virgülle ayrıldığı bir düz metin dosya biçimidir. Bir CSV dosyası, tipik olarak verileri tablo veya dikdörtgen matris biçiminde içerir. İlk satır sütun adlarını veya başlıkları içerebilir. Bu basit format, CSV dosyalarının okunmasını ve yazılmasını kolaylaştırır ve uygulamalar arasında veri alışverişi için yaygın olarak kullanılırlar.
#
# Simple CSV example:
#
# ```CSV
# Name,Age,Occupation
# Alice,30,Engineer
# Bob,25,Scientist
# Charlie,35,Artist
# ```
#
# Bu örnekte, ilk satır başlıkları içerirken, takip eden her satır üç alanda (İsim, Yaş, Meslek) bir kişinin bilgilerini temsil eder. Verilerin görselleştirilmesi basittir: bunu dikdörtgen bir tablo veya elektronik tablo olarak düşünebiliriz.

# %%
balik_2023 = pd.read_csv("https://acikveri.bizizmir.com/tr/datastore/dump/fc85a6e6-9061-489b-9508-e41b7f6fc67d?bom=True")
balik_2024 = pd.read_csv("https://acikveri.bizizmir.com/tr/datastore/dump/f7f664c3-8589-482b-a21a-36b2b62e0055?bom=True")
balik_2024.head()
# Out:
#    _id                TARIH  MAL_TURU          MAL_ADI BIRIM  ASGARI_UCRET  \
# 0    1  2024-01-02T00:00:00     BALIK    LAHOZ (DENİZ)    kg        550.00
# 1    2  2024-01-02T00:00:00     BALIK  SİNARİT (DENİZ)    kg        600.00
# 2    3  2024-01-02T00:00:00  TATLI SU  SAZAN ( TATLI )    kg         50.00
# 3    4  2024-01-02T00:00:00     BALIK   LÜFER(İRİ BOY)    kg        300.00
# 4    5  2024-01-02T00:00:00     BALIK     KAMİT(DENİZ)    kg         29.17
#
#    AZAMI_UCRET  ORTALAMA_UCRET
# 0       600.00          575.00
# 1       600.00          600.00
# 2       100.00           75.00
# 3       300.00          300.00
# 4        29.17           29.17

# %%
balik_2024.loc[:,"MAL_ADI"]
# Out:
# 0         LAHOZ (DENİZ)
# 1       SİNARİT (DENİZ)
# 2       SAZAN ( TATLI )
# 3        LÜFER(İRİ BOY)
# 4          KAMİT(DENİZ)
#              ...
# 3170     LÜFER ( DENİZ)
# 3171    SOMON ( TATLI )
# 3172       AKYA (DENİZ)
# 3173      TOMBIK(DENİZ)
# 3174    İSPENDEK(DENİZ)
# Name: MAL_ADI, Length: 3175, dtype: object

# %% [markdown]
# ##### EXCEL
#
# Microsoft'un EXCEL formatında ```.xlsx``` uzantılı dosyalar ile çalışmak istediğimiz pandas kütüphanesinin araçlarını kullanabiliriz. Bu örnekte, İstanbul Büyükşehirt Belediyesinin sunduğu verilerden bir örnek alalım.

# %%
xls = pd.read_excel("https://data.ibb.gov.tr/dataset/321aa12d-a388-4c61-b915-522730b8230a/resource/f676e493-8995-4e50-90b3-5381da92627f/download/rayl-sistemler-hat-bazl-sefer-saylar.xlsx")
xls['Tarih'] = pd.to_datetime(xls['Tarih'])
xls.index = xls['Tarih']
xls.drop(columns="Tarih", inplace=True)
xls.fillna(0, inplace=True)
metrolar = ["M"+str(i)for i in range(1,6)]
kismi_xls=xls.loc[:, metrolar]
kismi_xls
# Out:
#                M1     M2     M3     M4       M5
# Tarih
# 2017-01-01  21575  22479  16561  11762      0.0
# 2017-02-01  19488  20288  15012  10644      0.0
# 2017-03-01  21582  22846  16689  11820      0.0
# 2017-04-01  20870  21680  15967  11413      0.0
# 2017-05-01  21568  22588  16575  11784      0.0
# ...           ...    ...    ...    ...      ...
# 2021-12-01  21765  19130   8378  11692  11229.0
# 2022-01-01  21648  18938   8138  11448  11074.0
# 2022-02-01  19599  17164   7572  10508  10111.0
# 2022-03-01  21677  19084   8378  11755  11099.0
# 2022-04-01  21295  18774   8150  11558  10995.0
#
# [64 rows x 5 columns]

# %%
# %matplotlib inline
kismi_xls.plot(figsize=(20,4))
# Out:
# <Axes: xlabel='Tarih'>

# %% [markdown]
# ##### SQL, JSON, PARQUET
#
# ```sqlite3 sqlalchemy duckdb mongodb``` gibi pythonda ilişkisel olan ve olmaayan veri tabanları için paketler mevcut. Veri yapıları konusunda detaylı şekilde ele anılanacaktır. Bizler burada küçük bir gösterim yapacağız.

# %%
import os
from sqlalchemy import create_engine

DataFolderName="../data/data-type"

def rfd(filename):
    return os.path.join(DataFolderName, filename)

if not os.path.exists(DataFolderName):
    os.mkdir(DataFolderName)

os.listdir(DataFolderName)
# Out:
# []

# %% [markdown]
# ##### Elimizde ki veriyi farkli formatlari da kayit edelim

# %%
kismi_xls.to_csv(rfd("csv-example.csv"))
kismi_xls.to_json(rfd("json-example.json"))
kismi_xls.to_parquet(rfd("parquet-example.parquet"), engine='auto',index=False)

# %%
# Bir swl database olusturalim ve icerisi dataframe'leri gonderelim
engine=create_engine(os.path.join("sqlite:///", DataFolderName, "sql-example.sqlite"), echo=True)
kismi_xls.to_sql("kismi-veri", con=engine, index=False)

# birden fazla dataframe ekleyeabiliriz:
engine=create_engine(os.path.join("sqlite:///", DataFolderName, "sql-example-multi.sqlite"), echo=True)
kismi_xls.to_sql("kismi-veri", con=engine, index=False)
xls.to_sql("full-veri", con=engine, index=False)
# Out:
# 2024-02-24 21:14:39,331 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-02-24 21:14:39,333 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("kismi-veri")
# 2024-02-24 21:14:39,334 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-02-24 21:14:39,334 INFO sqlalchemy.engine.Engine COMMIT
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Bir swl database olusturalim ve icerisi dataframe'leri gonderelim
#       2 engine=create_engine(os.path.join("sqlite:///", DataFolderName, "sql-example.sqlite"), echo=True)
# ----> 3 kismi_xls.to_sql("kismi-veri", con=engine, index=False)
#       5 # birden fazla dataframe ekleyeabiliriz:
#       6 engine=create_engine(os.path.join("sqlite:///", DataFolderName, "sql-example-multi.sqlite"), echo=True)
#
# ...

# %%
engine=create_engine(os.path.join("sqlite:///", DataFolderName, "sql-example.sqlite"), echo=False)
data_sql = pd.read_sql("kismi-veri", con=engine)
data_sql.head()
# Out:
#       M1     M2     M3     M4   M5
# 0  21575  22479  16561  11762  0.0
# 1  19488  20288  15012  10644  0.0
# 2  21582  22846  16689  11820  0.0
# 3  20870  21680  15967  11413  0.0
# 4  21568  22588  16575  11784  0.0

# %% [markdown]
# #### JSON
#
# JSON, insan tarafından okunabilir olması için tasarlanmış metin tabanlı bir formattır. JavaScript'ten türetilmiştir, ancak bağımsız olarak ve birçok programlama dili arasında bir veri değişim formatı olarak kullanılabilir. JSON, verileri depolamak için anahtar-değer çiftleri kullanır ve doğası gereği hiyerarşiktir, yani veriler görsel olarak bir ağaç yapısı olarak temsil edilebilir.
#
# ```
# [
#   {
#     "Name": "Alice",
#     "Age": 30,
#     "Occupation": "Engineer"
#   },
#   {
#     "Name": "Bob",
#     "Age": 25,
#     "Occupation": "Scientist"
#   },
#   {
#     "Name": "Charlie",
#     "Age": 35,
#     "Occupation": "Artist"
#   }
# ]
# ```
# Bu örnekte, her bir kişinin bilgileri anahtar-değer çiftleri içeren bir nesne olarak saklanır ve tüm veri kümesi bir JSON dizisi olarak temsil edilir. CSV'den farklı olarak, JSON verileri dikdörtgen bir tablo yerine bir ağaç yapısı olarak görselleştirilir.

# %% [markdown]
# #### PARQUET
# Parquet veri tipi, karmaşık iç içe veri yapılarına sahip iken temelde csv formatına dayanmaktadır. Ancak, diskte yer alması konusunda parquet daha az boyuta sahip olması ile başarılıdır. Diğer taraftan, csv dosyası basitçe açılıp değişiklik yapılabilinirken parquet karmaşık veri yappılarını tutmak için sütun bazlı verileri saklar ve csv kadar kolay değlidir.
#
# Veri biliminde verilerinizi bir veri tabanında ya da bir bulut sağlayıcısında tutmanız gerektiğinde, CSV dosya formatı epey pahalıya gelecektir.

# %% [markdown]
# ![](../images/row-column-store.png)
# [Kaynakça](https://www.codeproject.com/KB/database/334875/image003.jpg)
#
# ![](../images/amazon-price.png)
# [Kaynakça](https://dzone.com/articles/how-to-be-a-hero-with-powerful-parquet-google-and)

# %%
pd.read_parquet(rfd("parquet-example.parquet"))
# Out:
#        M1     M2     M3     M4       M5
# 0   21575  22479  16561  11762      0.0
# 1   19488  20288  15012  10644      0.0
# 2   21582  22846  16689  11820      0.0
# 3   20870  21680  15967  11413      0.0
# 4   21568  22588  16575  11784      0.0
# ..    ...    ...    ...    ...      ...
# 59  21765  19130   8378  11692  11229.0
# 60  21648  18938   8138  11448  11074.0
# 61  19599  17164   7572  10508  10111.0
# 62  21677  19084   8378  11755  11099.0
# 63  21295  18774   8150  11558  10995.0
#
# [64 rows x 5 columns]

# %% [markdown]
# Kısa bir özet
#
# ------------------------------------------------------------------------------
# | Özellik            | CSV          | Parquet      | JSON         |
# |---------------------|--------------|--------------|--------------|
# | Veri yapısı        | Satır tabanlı | Sütun tabanlı | Nesne tabanlı |
# | Okunabilirlik       | Kolay        | Kolay        | Kolay        |
# | Depolama boyutu     | Büyük        | Küçük        | Orta         |
# | Okuma performansı   | Yavaş        | Hızlı        | Orta         |
# | Yazma performansı   | Hızlı        | Yavaş        | Orta         |
# | Uygunluk            | Genel amaçlı  | Büyük veri işleme | Genel amaçlı |
# ------------------------------------------------------------------------------

# %% [markdown]
# #### XML
#
# XML, HTML'ye benzer şekilde, verilerin yapısını tanımlamak için etiketler kullanan bir işaretleme dilidir. XML hiyerarşiktir ve bir XML belgesinde yer alan veriler görsel olarak bir ağaç yapısı şeklinde gösterilebilir. XML çok yönlüdür ve çok çeşitli veri yapılarını temsil etmek için kullanılabilir.
#
# ```xml
# <people>
#   <person>
#     <Name>Alice</Name>
#     <Age>30</Age>
#     <Occupation>Engineer</Occupation>
#   </person>
#   <person>
#     <Name>Bob</Name>
#     <Age>25</Age>
#     <Occupation>Scientist</Occupation>
#   </person>
#   <person>
#     <Name>Charlie</Name>
#     <Age>35</Age>
#     <Occupation>Artist</Occupation>
#   </person>
# </people>
# ```
#
# XML'in birçok çeşidi vardır. XML'in en ünlü ve yaygın olarak kullanılan çeşidi [Hypertext Markup Language (HTML)](https://en.wikipedia.org/wiki/HTML)'dir. XML başlıca bir ders olarak düşünebiliriz. Küçük bir örnek göstereceğiz. Python ile XML ile uğraşmak için en güvenli yöntem [xmltodict](https://github.com/martinblech/xmltodict) kütüphanesi aracılığıyla onu bir sözlüğe (veya bir hash haritasına) dönüştürmektir.

# %%
with urlopen("http://www.ecb.europa.eu/stats/eurofxref/eurofxref-daily.xml") as url:
    raw = url.read()

# %%
raw
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<gesmes:Envelope xmlns:gesmes="http://www.gesmes.org/xml/2002-08-01" xmlns="http://www.ecb.int/vocabulary/2002-08-01/eurofxref">\n\t<gesmes:subject>Reference rates</gesmes:subject>\n\t<gesmes:Sender>\n\t\t<gesmes:name>European Central Bank</gesmes:name>\n\t</gesmes:Sender>\n\t<Cube>\n\t\t<Cube time=\'2024-02-23\'>\n\t\t\t<Cube currency=\'USD\' rate=\'1.0834\'/>\n\t\t\t<Cube currency=\'JPY\' rate=\'162.91\'/>\n\t\t\t<Cube currency=\'BGN\' rate=\'1.9558\'/>\n\t\t\t<Cube currency=\'CZK\' rate=\'25.354\'/>\n\t\t\t<Cube currency=\'DKK\' rate=\'7.4544\'/>\n\t\t\t<Cube currency=\'GBP\' rate=\'0.85340\'/>\n\t\t\t<Cube currency=\'HUF\' rate=\'388.47\'/>\n\t\t\t<Cube currency=\'PLN\' rate=\'4.3118\'/>\n\t\t\t<Cube currency=\'RON\' rate=\'4.9744\'/>\n\t\t\t<Cube currency=\'SEK\' rate=\'11.1545\'/>\n\t\t\t<Cube currency=\'CHF\' rate=\'0.9522\'/>\n\t\t\t<Cube currency=\'ISK\' rate=\'148.50\'/>\n\t\t\t<Cube currency=\'NOK\' rate=\'11.3890\'/>\n\t\t\t<Cube 
# ...

# %%
dict = xmltodict.parse(raw)
dict
# Out:
# {'gesmes:Envelope': {'@xmlns:gesmes': 'http://www.gesmes.org/xml/2002-08-01',
#   '@xmlns': 'http://www.ecb.int/vocabulary/2002-08-01/eurofxref',
#   'gesmes:subject': 'Reference rates',
#   'gesmes:Sender': {'gesmes:name': 'European Central Bank'},
#   'Cube': {'Cube': {'@time': '2024-02-23',
#     'Cube': [{'@currency': 'USD', '@rate': '1.0834'},
#      {'@currency': 'JPY', '@rate': '162.91'},
#      {'@currency': 'BGN', '@rate': '1.9558'},
#      {'@currency': 'CZK', '@rate': '25.354'},
#      {'@currency': 'DKK', '@rate': '7.4544'},
#      {'@currency': 'GBP', '@rate': '0.85340'},
#      {'@currency': 'HUF', '@rate': '388.47'},
#      {'@currency': 'PLN', '@rate': '4.3118'},
#      {'@currency': 'RON', '@rate': '4.9744'},
#      {'@currency': 'SEK', '@rate': '11.1545'},
#      {'@currency': 'CHF', '@rate': '0.9522'},
#      {'@currency': 'ISK', '@rate': '148.50'},
#      {'@currency': 'NOK', '@rate': '11.3890'},
#      {'@currency': 'TRY', '@rate': '33.6842'},
# ...

# %%
pd.DataFrame.from_dict(dict['gesmes:Envelope']['Cube']['Cube']['Cube'])
# Out:
#    @currency     @rate
# 0        USD    1.0834
# 1        JPY    162.91
# 2        BGN    1.9558
# 3        CZK    25.354
# 4        DKK    7.4544
# 5        GBP   0.85340
# 6        HUF    388.47
# 7        PLN    4.3118
# 8        RON    4.9744
# 9        SEK   11.1545
# 10       CHF    0.9522
# 11       ISK    148.50
# 12       NOK   11.3890
# 13       TRY   33.6842
# 14       AUD    1.6467
# 15       BRL    5.3831
# 16       CAD    1.4587
# 17       CNY    7.7972
# 18       HKD    8.4760
# 19       IDR  16907.87
# 20       ILS    3.9322
# 21       INR   89.8170
# 22       KRW   1440.95
# 23       MXN   18.5089
# 24       MYR    5.1759
# 25       NZD    1.7445
# 26       PHP    60.562
# 27       SGD    1.4553
# 28       THB    39.013
# 29       ZAR   20.8672

# %% [markdown]
# ## YAML (YAML Ain't Markup Language)
#
# YAML insan tarafından okunabilir bir veri serileştirme formatıdır. Verilerin hiyerarşik yapısını temsil etmek için girinti ve basit noktalama işaretleri kullanır. YAML'nin okunması ve yazılması kolaydır ve genellikle yapılandırma dosyaları, diller arasında veri alışverişi ve veri depolama için kullanılır.
#
# ```yaml
# - Name: Alice
#   Age: 30
#   Occupation: Engineer
# - Name: Bob
#   Age: 25
#   Occupation: Scientist
# - Name: Charlie
#   Age: 35
#   Occupation: Artist
# ```
# Bu örnekte, her öğe bir kısa çizgi ve girinti ile temsil edilmektedir. JSON ve XML gibi, YAML verileri de bir ağaç yapısı olarak görselleştirilir.
#
# YAML genellikle config dosyaları için kullanılır.

# %% [markdown]
# ### Yapısız veri formatları
# Yapılandırılmamış veri dosyaları bir dizi bitten oluşur. Dosya, bitleri birbirinden herhangi bir şekilde ayırmaz. Dosyanın içine bakıp herhangi bir yapı göremezsiniz çünkü görecek bir şey yoktur. Yapılandırılmamış dosya formatları dosya kullanıcısının verileri nasıl yorumlayacağını bilmesine bağlıdır. Belirli bir düzen veya şemaya sahip olmayan(tabular olmayan), çeşitli türde verileri ifade etmek için kullanılan format [yapısız veri](https://en.wikipedia.org/wiki/Unstructured_data) olarak tanımlanabilir. Örneğin resim, video, ses kayıtları, sensör kayıtları, metin vb olabilmektedir.
#
#
# Python'da [unstructured](https://unstructured-io.github.io/unstructured/index.html) kütüphanesi yapısız veri türleri için ön hazırlık aşamsında kullanılmak üzere oluşturulmuş paketlerden bir tanesidir.
#
# ![](../images/unstructured-data-types.png)
# [Kaynakça](https://unstructured-io.github.io/unstructured/index.html)

# %% [markdown]
# #### NIFTI: MRI verileri
#
# MRI verileri ile çalışmak başlıbaşına bir ayrı ders olarak düşünülebilir. Burada giriş niteliğinde bir örnekle inceleceğiz. MRI verileri başlangıçta saklanırken uzantısız olarak DICOM formatındadır. Genelde bu format ile analiz yapılamadığından NIFTI formatına dönüştürülür. [dcm2niix](https://pypi.org/project/dcm2niix/) paketi kullanarak dönüşüm sağlandıktan sonra [nibabel](https://pypi.org/project/nibabel/) paketi ile NIfTI görüntülerini okuma yazma içeren işlemleri küçük bir örnek ile gösterebiliriz. MRI verilerini açık kaynak olarak sunulan [Princeton Handbook for Reproducible Neuroimaging](https://brainhack-princeton.github.io/handbook/) kitabından elde edeceğiz.
#
# [Machine learning for neuroimaging with scikit-learn](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3930868/)
#
# Kaynaklar:
# * https://carpentries-incubator.github.io/SDC-BIDS-IntroMRI/aio/index.html
# * https://lukas-snoek.com/NI-edu/fMRI-introduction/week_1/python_for_mri.html
# * https://dev.to/narendraanupoju/mri-data-processing-with-python-1jgg
# * https://dartbrains.org/content/Introduction_to_Neuroimaging_Data.html
# * https://nipy.org/nibabel/coordinate_systems.html

# %%
# !wget 'https://zenodo.org/record/3677090/files/0219191_mystudy-0219-1114.tar.gz' -O ../data/0219191_mystudy-0219-1114.tar.gz
# !mkdir -p ../data/dicom_examples
# !tar -xvzf ../data/0219191_mystudy-0219-1114.tar.gz -C ../data/dicom_examples
# !gzip -d ../data/dicom_examples/0219191_mystudy-0219-1114/dcm/*dcm.gz
#!rm ../data/0219191_mystudy-0219-1114.tar.gz
# Out:
# x 0219191_mystudy-0219-1114/
# x 0219191_mystudy-0219-1114/.DS_Store
# x 0219191_mystudy-0219-1114/gzip-report.log
# x 0219191_mystudy-0219-1114/TransferStatus.log
# x 0219191_mystudy-0219-1114/dcm/
# x 0219191_mystudy-0219-1114/dcm/12-320-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/11-118-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/7-5-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/5-32-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/9-188-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/12-393-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/8-10-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/5-189-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/9-34-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/12-86-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/13-178-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/13-84-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/11-262-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/5-129-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/12-256-1.dcm.gz
# x 0219191_mystudy-0219-1114/dcm/7-3-1.dcm.gz
# ...

# %%
# DCOM formatindan nifti formatina donusum
# !mkdir -p ../data/dicom_examples/nii
# !dcm2niix -z y -o ../data/dicom_examples/nii ../data/dicom_examples/0219191_mystudy-0219-1114/
# Out:
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# Found 2661 DICOM file(s)
# Convert 192 DICOM as ../data/dicom_examples/nii/0219191_mystudy-0219-1114_anat_ses-01_T1w_20190219111436_5 (256x256x192x1)
# Slices not stacked: orientation varies (vNav or localizer?) [0.999714 -0.00832137 0.0224079 0.00569606 0.993375 0.114773] != [0.999146 -0.0147051 0.0386074 -0.000473197 0.930373 0.366613]
# Convert 1 DICOM as ../data/dicom_examples/nii/0219191_mystudy-0219-1114_anat_ses-01_scout_20190219111436_4_i00002 (162x162x1x1)
# ...
# Convert 1 DICOM as ../data/dicom_examples/nii/0219191_mystudy-0219-1114_anat_ses-01_scout_20190219111436_4_i00003 (162x162x1x1)
# ...
# Convert 1 DICOM as ../data/dicom_examples/nii/0219191_mystudy-0219-1114_anat_ses-01_scout_20190219111436_4_i00001 (162x162x1x1)
# ...

# %%
# nifti formatinda olan verileri calisma alanimiza yuklemek
import nibabel as nib
mri_1 = nib.load("../data/dicom_examples/nii/0219191_mystudy-0219-1114_anat_ses-01_T1w_20190219111436_5.nii.gz")

# ilk yüklenen veri hakkında detaylı bilgiye kolayca ulaşabiliriz.
print(mri_1)
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# data shape (192, 256, 256)
# affine:
# [[ 8.99742186e-01  1.05651410e-03  2.05146018e-02 -9.00501251e+01]
#  [-7.48920813e-03  8.19935203e-01  2.57255703e-01 -1.43966370e+02]
#  [-2.01671515e-02 -2.57352889e-01  8.19709778e-01 -7.67913361e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# metadata:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 54
# dim             : [  3 192 256 256   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.         0.90000004 0.859375   0.859375   2.3        0.
#  0.         0.        ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# ...

# %%
# MRI görüntüsüne çekmek istediğimizde
mri_veri=mri_1.get_fdata()
mri_veri.shape
# Out:
# (192, 256, 256)

# %%
# %matplotlib inline
plt.imshow(mri_veri[160,:,:].T, cmap="gray")
plt.show()

# %% [markdown]
# <img src="../images/tensors.png"  width=700/>

# %%
#https://nipy.org/nibabel/coordinate_systems.html
def show_slices(slices):
   """ Function to display row of image slices """
   fig, axes = plt.subplots(1, len(slices))
   for i, slice in enumerate(slices):
       axes[i].imshow(slice.T, cmap="gray", origin="lower")

slice_0 = mri_veri[26, :, :]
slice_1 = mri_veri[:, 30, :]
slice_2 = mri_veri[:, :, 16]
show_slices([slice_0, slice_1, slice_2])
plt.suptitle("Axis0, Axis1, Axis 2")
# Out:
# Text(0.5, 0.98, 'Axis0, Axis1, Axis 2')

# %%
# https://nilearn.github.io/stable/index.html
# NeuroImage için kullanışlı bir paket sklearn gibi düşünebiliriz.
from nilearn.datasets import MNI152_FILE_PATH
print(f"Path to MNI152 template: {MNI152_FILE_PATH!r}")

from nilearn.plotting import plot_img, view_img
plot_img(MNI152_FILE_PATH)
# Out:
# Path to MNI152 template: '/opt/homebrew/anaconda3/envs/yzup-veri/lib/python3.11/site-packages/nilearn/datasets/data/mni_icbm152_t1_tal_nlin_sym_09a_converted.nii.gz'

# %%
view_img(mri_1)
plot_img(mri_1)
# Out:
# /opt/homebrew/anaconda3/envs/yzup-veri/lib/python3.11/site-packages/numpy/core/fromnumeric.py:771: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /opt/homebrew/anaconda3/envs/yzup-veri/lib/python3.11/site-packages/nilearn/image/resampling.py:756: UserWarning: Casting data from int32 to float32
#   return resample_img(
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
# ...
