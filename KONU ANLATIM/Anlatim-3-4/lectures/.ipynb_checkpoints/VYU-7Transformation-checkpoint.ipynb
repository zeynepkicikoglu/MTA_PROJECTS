# %% [markdown]
# ## Transformation
# Doğrusal ve lojistik regresyon değişkenlerin normal dağıldığını varsayar. Eğer değillerse, dağılımlarını Gauss dagilimina dönüştürmek için genellikle matematiksel bir dönüşüm uygulayabiliriz. Bu sekilde hatta bazen değişkenler ile hedefleri arasındaki doğrusal ilişkileri ortaya çıkarabiliriz. Bu, değişkenleri dönüştürmenin doğrusal makine öğrenimi modellerinin performansını artırabileceği anlamına gelir. Yaygın olarak kullanılan matematiksel dönüşümler arasında logaritma, ters alma, kuvvet, kare ve küp kök dönüşümlerinin yanı sıra Box-Cox ve Yeo-Johnson dönüşümleri de yer alır.
#
# <img src='../images/logtrans.png'>
#
# [Kaynakca](https://www.researchgate.net/publication/308007227_Exploratory_Data_Analysis)

# %%
# To get multi output in jupyternotebook
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# sklearn ciktisini nnumpy array olarak donmektedir. Bu adimi pandas icin ayarlayabiliriz.
from sklearn import set_config
set_config(transform_output="pandas")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from distfit import distfit

# %% [raw]
# import pandas as pd
# import numpy as np
#
# data_url = "http://lib.stat.cmu.edu/datasets/boston"
# raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
# data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
# target = raw_df.values[1::2, 2]
# column_names = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
# data=pd.DataFrame(data)
# data['class']=target
# data.columns=column_names
# data.info()
# data.to_csv('../data/feature-engine/boston.csv', index=False)

# %%
data=pd.read_csv('../data/feature-engine/boston.csv')
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
def diagnostic_plots(df, variable): 
    plt.figure(figsize=(6,3))
    plt.subplot(1, 2, 1)
    df[variable].hist(bins=30)
    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.show()
diagnostic_plots(data, 'LSTAT')

# %%
def dist_check(df, variable):
    dfit = distfit()
    results = dfit.fit_transform(df[variable].to_numpy())
    results['summary']
    dfit.plot(fontsize=15, figsize=(6, 3))

# %%
dist_check(data, 'LSTAT')
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm      ] [0.00 sec] [RSS: 0.00150247] [loc=12.653 scale=7.134]
# [distfit] >INFO> [expon     ] [0.00 sec] [RSS: 0.00393038] [loc=1.730 scale=10.923]
# [distfit] >INFO> [pareto    ] [0.00 sec] [RSS: 0.00393038] [loc=-1073741822.270 scale=1073741824.000]
# [distfit] >INFO> [dweibull  ] [0.01 sec] [RSS: 0.00100743] [loc=11.851 scale=6.118]
# [distfit] >INFO> [t         ] [0.08 sec] [RSS: 0.00134872] [loc=12.214 scale=6.524]
# [distfit] >INFO> [genextreme] [0.03 sec] [RSS: 0.000506226] [loc=9.162 scale=5.225]
# [distfit] >INFO> [gamma     ] [0.00 sec] [RSS: 0.00020233] [loc=1.392 scale=4.876]
# [distfit] >INFO> [lognorm   ] [0.00 sec] [RSS: 0.000402476] [loc=-1.734 scale=12.730]
# [distfit] >INFO> [beta      ] [0.01 sec] [RSS: 0.000132179] [loc=1.617 scale=60.197]
# [distfit] >INFO> [uniform   ] [0.00 sec] [RSS: 0.00688187] [loc=1.730 scale=36.240]
# ...

# %% [markdown]
# Matematiksel donusumler
# $$x \rightarrow \log(x)$$
# $$x \rightarrow \frac{1}{x}$$
# $$x \rightarrow \sqrt{x}$$
# $$x \rightarrow x^{1/3}$$

# %%
x=np.linspace(0.1,2,5)
x
np.log(x) 
np.reciprocal(x)  # 1/x
np.power(x, 1/2) # square root
np.power(x, 1/3) # cube root
# Out:
# array([0.1  , 0.575, 1.05 , 1.525, 2.   ])
# array([-2.30258509, -0.55338524,  0.04879016,  0.42199441,  0.69314718])
# array([10.        ,  1.73913043,  0.95238095,  0.6557377 ,  0.5       ])
# array([0.31622777, 0.75828754, 1.02469508, 1.2349089 , 1.41421356])
# array([0.46415888, 0.83155175, 1.01639636, 1.15103876, 1.25992105])

# %%
data_tf = data.copy()
from sklearn.preprocessing import FunctionTransformer
transformer = FunctionTransformer(func=np.log)
data_tf['LSTAT']=transformer.transform(data_tf['LSTAT'])
diagnostic_plots(data_tf, 'LSTAT')

# %%
data_tf = data.copy()
from sklearn.preprocessing import FunctionTransformer
transformer = FunctionTransformer(func=np.reciprocal)
data_tf['LSTAT']=transformer.transform(data_tf['LSTAT'])
diagnostic_plots(data_tf, 'LSTAT')

# %%
data_tf = data.copy()
from sklearn.preprocessing import FunctionTransformer
transformer = FunctionTransformer(func=lambda x: np.power(x, 1/2))
data_tf['LSTAT']=transformer.transform(data_tf['LSTAT'])
diagnostic_plots(data_tf, 'LSTAT')

# %% [markdown]
# Verileri  normal dagilima en yakin dagilima sahip sekilde donusturme icin Box-Cox ve Yeo-Johnson donusumleri mecuttur. Bu donusumler veriden

# %%
data_tf = data.copy()
from sklearn.preprocessing import PowerTransformer
transformer = PowerTransformer(method='yeo-johnson')
data_tf[['LSTAT']]=transformer.fit_transform(data_tf[['LSTAT']])
diagnostic_plots(data_tf, 'LSTAT')
dist_check(data_tf, 'LSTAT')
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm      ] [0.00 sec] [RSS: 0.0135133] [loc=-0.000 scale=1.000]
# [distfit] >INFO> [expon     ] [0.00 sec] [RSS: 0.396132] [loc=-2.496 scale=2.496]
# [distfit] >INFO> [pareto    ] [0.00 sec] [RSS: 0.396132] [loc=-1073741826.496 scale=1073741824.000]
# [distfit] >INFO> [dweibull  ] [0.01 sec] [RSS: 0.0241921] [loc=-0.000 scale=0.910]
# [distfit] >INFO> [t         ] [0.08 sec] [RSS: 0.0135133] [loc=-0.000 scale=1.000]
# [distfit] >INFO> [genextreme] [0.02 sec] [RSS: 0.0103432] [loc=-0.340 scale=1.006]
# [distfit] >INFO> [gamma     ] [0.02 sec] [RSS: 0.0136612] [loc=-115.919 scale=0.009]
# [distfit] >INFO> [lognorm   ] [0.03 sec] [RSS: 0.0139936] [loc=-72.168 scale=72.163]
# [distfit] >INFO> [beta      ] [0.00 sec] [RSS: 0.00708888] [loc=-2.744 scale=5.408]
# [distfit] >INFO> [uniform   ] [0.00 sec] [RSS: 0.181982] [loc=-2.496 scale=4.883]
# ...

# %%
data[['NOX','DIS','LSTAT']].hist(bins=30, figsize=(6,4));

# %%
data_tf = data.copy()
data_tf = data_tf[['NOX','DIS','LSTAT']]
from sklearn.preprocessing import PowerTransformer
transformer = PowerTransformer(method='yeo-johnson')
data_tf=transformer.fit_transform(data_tf)
data_tf.hist(bins=30, figsize=(6,4));

# %% [markdown]
# Teorik olarak normallik testi yapmak istiyorsak Shapiro-Wilk, Kolmogorov-Smirnov gibi testlere basvurabiliriz. Hizli bir giris olarak [surayi](https://machinelearningmastery.com/a-gentle-introduction-to-normality-tests-in-python/) ziyaret edebilirsiniz

# %%
from scipy.stats import shapiro  # Shapiro-Wilk Test
from scipy.stats import normaltest

variable=data_tf[['LSTAT']]
# normality test
stat, p = shapiro(variable)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
 print('Sample looks Gaussian (fail to reject H0)')
else:
 print('Sample does not look Gaussian (reject H0)')

stat, p = normaltest(variable)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.991, p=0.005
# Sample does not look Gaussian (reject H0)
# Statistics=18.611, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Örnek veri setini oluşturalım
np.random.seed(0)
data = pd.DataFrame({
    'feature0': np.random.exponential(scale=1, size=1000),  # Sağa çarpık dağılım
    'feature1': np.random.normal(loc=0, scale=1, size=1000),  # Normal dağılım
    'target': np.random.randint(0, 2, size=1000)
})

# Veri setini eğitim ve test setlerine bölelim
X_train, X_test, y_train, y_test = train_test_split(data.drop('target', axis=1), data['target'], test_size=0.3, random_state=0)

from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegressionCV


# Modeli eğitelim
#model = RandomForestClassifier(random_state=42)
model = LogisticRegressionCV()

model.fit(X_train, y_train)

# Train seti üzerinde modeli değerlendirelim
y_t_pred = model.predict(X_train)
accuracy = accuracy_score(y_train, y_t_pred)
print("Model accuracy default:", accuracy)

# Test seti üzerinde modeli değerlendirelim
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Model accuracy default:", accuracy)


# Eğitim setindeki 'feature0' üzerinde logaritmik dönüşüm yapalım
X_train['log_feature0'] = np.log(X_train['feature0'] + 1)  # +1 ekleme log(0) hatası almamak için
X_test['log_feature0'] = np.log(X_test['feature0'] + 1)

# Eğitim setindeki 'feature1' üzerinde normal dağılım parametrelerini kullanarak yeni bir özellik oluşturalım
mean = X_train['feature1'].mean()
std_dev = X_train['feature1'].std()
X_train['normal_probability_feature1'] = norm.cdf(X_train['feature1'], loc=mean, scale=std_dev)
X_test['normal_probability_feature1'] = norm.cdf(X_test['feature1'], loc=mean, scale=std_dev)


# Modeli eğitelim
#model = RandomForestClassifier(random_state=42)
model = LogisticRegressionCV()
model.fit(X_train, y_train)


# Train seti üzerinde modeli değerlendirelim
y_t_pred = model.predict(X_train)
accuracy = accuracy_score(y_train, y_t_pred)
print("Model accuracy default:", accuracy)


# Test seti üzerinde modeli değerlendirelim
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Model accuracy with the engined data:", accuracy)
# Out:
# LogisticRegressionCV()
# Model accuracy default: 0.5457142857142857
# Model accuracy default: 0.54
# LogisticRegressionCV()
# Model accuracy default: 0.5542857142857143
# Model accuracy with the engined data: 0.53
